# %%
import pandas as pd
import numpy as np

# %%
from pygeocoder import Geocoder
import pycountry

# %%
df=pd.DataFrame.from_csv('tsdec450.tsv', sep='\t', header=0)
df
# Out:
#                         1990    1991   1992   1993   1994    1995   1996   \
# age,unit,sex,geo\time
# TOTAL,PC_ACT,T,AT          :       :      :      :    4.3     4.2    4.7
# TOTAL,PC_ACT,T,BE        6.6     6.4    7.1    8.6    9.8     9.7    9.5
# TOTAL,PC_ACT,T,BG          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,CY          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,CZ          :       :      :    4.3    4.3     4.0    3.9
# TOTAL,PC_ACT,T,DE          :     5.5    6.6    7.8    8.4     8.2    8.9
# TOTAL,PC_ACT,T,DK        7.2     7.9    8.6    9.6    7.7     6.7    6.3
# TOTAL,PC_ACT,T,EA18        :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,EA19        :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,EE          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,EL          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,ES       15.5    15.5   17.0   20.8   22.0   20.7 i  19.9
# TOTAL,PC_ACT,T,EU27        :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,EU28        :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,FI        3.2     6.6   11.7   16.3   16.6    15.4   14.6
# TOTAL,PC_ACT,T,FR        7.9     8.1    9.0   10.1   10.4   10.2 i  10.5
# TOTAL,PC_ACT,T,HR          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,HU          :       :      :      :      :       :    9.9
# TOTAL,PC_ACT,T,IE       13.4    14.7   15.4   15.6   14.3    12.3   11.7
# TOTAL,PC_ACT,T,IS          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,IT       8.9 p   8.5 p   8.8    9.7   10.6    11.2   11.2
# TOTAL,PC_ACT,T,JP        2.1     2.1    2.2    2.5    2.9     3.1    3.4
# TOTAL,PC_ACT,T,LT          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,LU        1.7     1.6    2.1    2.6    3.2     2.9    2.9
# TOTAL,PC_ACT,T,LV          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,MT          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,NL        6.1     5.7    5.7    6.5    7.2     8.3    7.7
# TOTAL,PC_ACT,T,NO        5.2     5.5    5.9    6.0    5.4    4.9 b   4.7
# TOTAL,PC_ACT,T,PL          :       :      :      :      :       :      :
# TOTAL,PC_ACT,T,PT        5.6     5.0    5.0    6.3    7.6     7.9    8.0
# ...                       ...     ...    ...    ...    ...     ...    ...
# TOTAL,THS_PER,T,EA18       :       :      :      :      :       :      :
# TOTAL,THS_PER,T,EA19       :       :      :      :      :       :      :
# TOTAL,THS_PER,T,EE         :       :      :      :      :       :      :
# TOTAL,THS_PER,T,EL         :       :      :      :      :       :      :
# TOTAL,THS_PER,T,ES      2297    2313   2602   3230   3455   3279 i  3192
# TOTAL,THS_PER,T,EU27       :       :      :      :      :       :      :
# TOTAL,THS_PER,T,EU28       :       :      :      :      :       :      :
# TOTAL,THS_PER,T,FI        82     168    292    405    408     382    363
# TOTAL,THS_PER,T,FR      2007    2074   2314   2591   2696   2649 i  2763
# TOTAL,THS_PER,T,HR         :       :      :      :      :       :      :
# TOTAL,THS_PER,T,HU         :       :      :      :      :     391    395
# TOTAL,THS_PER,T,IE       176     197    209    216    203     177    174
# TOTAL,THS_PER,T,IS         :       :      :      :      :       :      :
# TOTAL,THS_PER,T,IT     2084 p  2023 p  2056   2296   2493    2616   2619
# TOTAL,THS_PER,T,JP      1341    1363   1423   1657   1921    2099   2250
# TOTAL,THS_PER,T,LT         :       :      :      :      :       :      :
# TOTAL,THS_PER,T,LU         3       3      3      4      5       5      5
# TOTAL,THS_PER,T,LV         :       :      :      :      :       :      :
# TOTAL,THS_PER,T,MT         :       :      :      :      :       7      8
# TOTAL,THS_PER,T,NL       409     391    400    458    517     620    575
# TOTAL,THS_PER,T,NO       112     116    126    127    116    108 b   106
# TOTAL,THS_PER,T,PL         :       :      :      :      :    2279   2241
# TOTAL,THS_PER,T,PT       273     249    244    307    373     388    394
# TOTAL,THS_PER,T,RO         :       :      :      :      :    1248    847
# TOTAL,THS_PER,T,SE        80     143    252    401    412     391    426
# TOTAL,THS_PER,T,SI         :       :      :      :      :      66     65
# TOTAL,THS_PER,T,SK         :       :      :      :      :     291    269
# TOTAL,THS_PER,T,TR         :       :      :      :      :       :      :
# TOTAL,THS_PER,T,UK      1967    2445   2710   2857   2611    2383   2228
# TOTAL,THS_PER,T,US      7047    8628   9613   8940   7997    7404   7236
#
#                        1997   1998    1999    ...      2007    2008    2009   \
# age,unit,sex,geo\time                         ...
# TOTAL,PC_ACT,T,AT       4.7    4.7     4.2    ...       4.9     4.1     5.3
# TOTAL,PC_ACT,T,BE       9.2    9.3     8.4    ...       7.5     7.0     7.9
# TOTAL,PC_ACT,T,BG         :      :       :    ...       6.9     5.6     6.8
# TOTAL,PC_ACT,T,CY         :      :       :    ...       3.9     3.7     5.4
# TOTAL,PC_ACT,T,CZ       4.8    6.5     8.7    ...       5.3     4.4     6.7
# TOTAL,PC_ACT,T,DE       9.6    9.4     8.6    ...       8.5     7.4     7.6
# TOTAL,PC_ACT,T,DK       5.2    4.9     5.2    ...       3.8     3.4     6.0
# TOTAL,PC_ACT,T,EA18       :      :     9.6    ...       7.5     7.6     9.6
# TOTAL,PC_ACT,T,EA19       :      :     9.7    ...       7.5     7.6     9.6
# TOTAL,PC_ACT,T,EE         :      :       :    ...       4.6    5.5 i   13.5
# TOTAL,PC_ACT,T,EL         :   11.1    12.0    ...       8.4     7.8     9.6
# TOTAL,PC_ACT,T,ES      18.4   16.4    13.6    ...       8.2    11.3    17.9
# TOTAL,PC_ACT,T,EU27       :      :       :    ...       7.2     7.0     9.0
# TOTAL,PC_ACT,T,EU28       :      :       :    ...       7.2     7.0     9.0
# TOTAL,PC_ACT,T,FI      12.7   11.4    10.2    ...       6.9     6.4     8.2
# TOTAL,PC_ACT,T,FR      10.7   10.3    10.0    ...       8.0     7.4     9.1
# TOTAL,PC_ACT,T,HR         :      :       :    ...       9.9     8.6     9.3
# TOTAL,PC_ACT,T,HU       9.1    8.7     6.9    ...       7.4    7.8 i   10.0
# TOTAL,PC_ACT,T,IE       9.9    7.5     5.6    ...       4.7     6.4    12.0
# TOTAL,PC_ACT,T,IS         :      :       :    ...       2.3     3.0     7.2
# TOTAL,PC_ACT,T,IT      11.2   11.3    10.9    ...       6.1     6.7     7.7
# TOTAL,PC_ACT,T,JP       3.4    4.1     4.7    ...       3.8     4.0     5.1
# TOTAL,PC_ACT,T,LT         :   13.2    14.6    ...       4.3     5.8    13.8
# TOTAL,PC_ACT,T,LU       2.7    2.7     2.4    ...       4.2     4.9     5.1
# TOTAL,PC_ACT,T,LV         :      :    14.1    ...       6.1     7.7    17.5
# TOTAL,PC_ACT,T,MT         :      :       :    ...       6.5     6.0     6.9
# TOTAL,PC_ACT,T,NL       6.5    5.1     4.2    ...       4.2     3.7     4.4
# TOTAL,PC_ACT,T,NO      3.9 b   3.1     3.0    ...       2.5     2.5     3.2
# TOTAL,PC_ACT,T,PL      10.9   10.2    13.4    ...       9.6     7.1    8.1 i
# TOTAL,PC_ACT,T,PT      7.5 i   6.1     5.5    ...       9.1     8.8    10.7
# ...                      ...    ...     ...   ...        ...     ...     ...
# TOTAL,THS_PER,T,EA18      :      :   13715    ...     11658   11863   15022
# TOTAL,THS_PER,T,EA19      :      :   13964    ...     11722   11951   15233
# TOTAL,THS_PER,T,EE        :      :       :    ...        32     38 i     93
# TOTAL,THS_PER,T,EL        :    502     548    ...       418     388     485
# TOTAL,THS_PER,T,ES     3007   2727    2310    ...      1846    2596    4154
# TOTAL,THS_PER,T,EU27      :      :       :    ...     16797   16585   21180
# TOTAL,THS_PER,T,EU28      :      :       :    ...     16987   16751   21360
# TOTAL,THS_PER,T,FI      314    285     261    ...       183     172     221
# TOTAL,THS_PER,T,FR     2802   2715    2656    ...      2268    2121    2622
# TOTAL,THS_PER,T,HR        :      :       :    ...       190     166     180
# TOTAL,THS_PER,T,HU      358    350     279    ...       312    326 i    418
# TOTAL,THS_PER,T,IE      152    123      96    ...       105     146     268
# TOTAL,THS_PER,T,IS        :      :       :    ...      4161    5505   13077
# TOTAL,THS_PER,T,IT     2641   2681    2593    ...      1481    1664    1907
# TOTAL,THS_PER,T,JP     2302   2789    3169    ...      2568    2658    3367
# TOTAL,THS_PER,T,LT        :    227     249    ...        64      88     211
# TOTAL,THS_PER,T,LU        5      5       4    ...         9      10      12
# TOTAL,THS_PER,T,LV        :      :     158    ...        68      88     193
# TOTAL,THS_PER,T,MT       10     10      11    ...        11      10      12
# TOTAL,THS_PER,T,NL      497    399     333    ...       355     318     381
# TOTAL,THS_PER,T,NO      89 b    72      71    ...        63      66      82
# TOTAL,THS_PER,T,PL     1849   1730    2300    ...      1579    1165   1359 i
# TOTAL,THS_PER,T,PT     374 i   308     281    ...       494     476     574
# TOTAL,THS_PER,T,RO      717    726     820    ...       634     549     624
# TOTAL,THS_PER,T,SE      437    362     300    ...       298     305     408
# TOTAL,THS_PER,T,SI       67     72      71    ...        50      46      61
# TOTAL,THS_PER,T,SK      279    315     414    ...       293     254     321
# TOTAL,THS_PER,T,TR        :      :       :    ...     2039 b   2293    3089
# TOTAL,THS_PER,T,UK     1927   1740    1696    ...      1624    1757    2369
# TOTAL,THS_PER,T,US     6739   6210    5879    ...      7077    8924   14264
#
#                         2010    2011     2012     2013     2014     2015   \
# age,unit,sex,geo\time
# TOTAL,PC_ACT,T,AT        4.8     4.6       4.9      5.4      5.6      5.7
# TOTAL,PC_ACT,T,BE        8.3     7.2       7.6      8.4      8.5      8.5
# TOTAL,PC_ACT,T,BG      10.3 i   11.3      12.3     13.0     11.4      9.2
# TOTAL,PC_ACT,T,CY        6.3     7.9      11.9     15.9     16.1     15.0
# TOTAL,PC_ACT,T,CZ        7.3     6.7       7.0      7.0      6.1      5.1
# TOTAL,PC_ACT,T,DE        7.0     5.8       5.4      5.2      5.0      4.6
# TOTAL,PC_ACT,T,DK        7.5     7.6       7.5      7.0      6.6      6.2
# TOTAL,PC_ACT,T,EA18     10.1    10.1      11.4     12.0     11.6     10.9
# TOTAL,PC_ACT,T,EA19     10.2    10.2      11.4     12.0     11.6     10.9
# TOTAL,PC_ACT,T,EE       16.7    12.3      10.0      8.6      7.4      6.2
# TOTAL,PC_ACT,T,EL       12.7    17.9      24.5     27.5     26.5     24.9
# TOTAL,PC_ACT,T,ES       19.9    21.4      24.8     26.1     24.5     22.1
# TOTAL,PC_ACT,T,EU27      9.6     9.6      10.4     10.8     10.2      9.4
# TOTAL,PC_ACT,T,EU28      9.6     9.7      10.5     10.9     10.2      9.4
# TOTAL,PC_ACT,T,FI        8.4     7.8       7.7      8.2      8.7      9.4
# TOTAL,PC_ACT,T,FR        9.3     9.2       9.8     10.3     10.3     10.4
# TOTAL,PC_ACT,T,HR       11.8    13.7      15.8     17.4     17.2     16.1
# TOTAL,PC_ACT,T,HU       11.2    11.0      11.0     10.2      7.7      6.8
# TOTAL,PC_ACT,T,IE       13.9    14.7      14.7     13.1     11.3      9.4
# TOTAL,PC_ACT,T,IS        7.6     7.1       6.0      5.4      5.0      4.0
# TOTAL,PC_ACT,T,IT        8.4     8.4      10.7     12.1     12.7     11.9
# TOTAL,PC_ACT,T,JP        5.0    4.6 b      4.3      4.0      3.6      3.4
# TOTAL,PC_ACT,T,LT       17.8    15.4      13.4     11.8     10.7      9.1
# TOTAL,PC_ACT,T,LU        4.6     4.8       5.1      5.9      6.0      6.5
# TOTAL,PC_ACT,T,LV       19.5    16.2      15.0     11.9     10.8      9.9
# TOTAL,PC_ACT,T,MT        6.9     6.4       6.3      6.4      5.8      5.4
# TOTAL,PC_ACT,T,NL        5.0     5.0       5.8      7.3      7.4      6.9
# TOTAL,PC_ACT,T,NO        3.6     3.3       3.2      3.5      3.5      4.4
# TOTAL,PC_ACT,T,PL        9.7     9.7      10.1     10.3      9.0      7.5
# TOTAL,PC_ACT,T,PT       12.0    12.9      15.8     16.4     14.1     12.6
# ...                       ...     ...      ...      ...      ...      ...
# TOTAL,THS_PER,T,EA18   15885   15957   17995.0  19072.0  18480.0  17317.0
# TOTAL,THS_PER,T,EA19   16156   16185   18192.0  19244.0  18638.0  17451.0
# TOTAL,THS_PER,T,EE       114      85      68.0     59.0     50.0     42.0
# TOTAL,THS_PER,T,EL       639     882    1195.0   1330.0   1274.0   1197.0
# TOTAL,THS_PER,T,ES      4640    5013    5811.0   6051.0   5610.0   5056.0
# TOTAL,THS_PER,T,EU27   22765   22868   24974.0  25984.0  24482.0  22575.0
# TOTAL,THS_PER,T,EU28   22989   23124   25266.0  26304.0  24807.0  22879.0
# TOTAL,THS_PER,T,FI       224     209     207.0    219.0    232.0    252.0
# TOTAL,THS_PER,T,FR      2680    2665    2855.0   3026.0   3032.0   3054.0
# TOTAL,THS_PER,T,HR       224     256     292.0    320.0    325.0    304.0
# TOTAL,THS_PER,T,HU       469     466     473.0    441.0    343.0    308.0
# TOTAL,THS_PER,T,IE       303     317     316.0    282.0    243.0    204.0
# TOTAL,THS_PER,T,IS     13674   12704   10874.0   9973.0   9276.0   7635.0
# TOTAL,THS_PER,T,IT      2056    2061    2691.0   3069.0   3236.0   3032.0
# TOTAL,THS_PER,T,JP      3347   3019 b   2848.0   2668.0   2380.0   2233.0
# TOTAL,THS_PER,T,LT       270     228     197.0    172.0    158.0    134.0
# TOTAL,THS_PER,T,LU        11      11      13.0     15.0     16.0     18.0
# TOTAL,THS_PER,T,LV       206     167     155.0    120.0    108.0     98.0
# TOTAL,THS_PER,T,MT        12      11      11.0     12.0     11.0     11.0
# TOTAL,THS_PER,T,NL       435     434     516.0    647.0    660.0    614.0
# TOTAL,THS_PER,T,NO        93      87      85.0     95.0     96.0    121.0
# TOTAL,THS_PER,T,PL      1650    1659    1749.0   1793.0   1567.0   1304.0
# TOTAL,THS_PER,T,PT       645     688     835.0    855.0    729.0    648.0
# TOTAL,THS_PER,T,RO       652     659     627.0    653.0    629.0    624.0
# TOTAL,THS_PER,T,SE       425     390     403.0    411.0    411.0    387.0
# TOTAL,THS_PER,T,SI        75      83      90.0    102.0     98.0     90.0
# TOTAL,THS_PER,T,SK       386    363 i    378.0    386.0    359.0    314.0
# TOTAL,THS_PER,T,TR      2739    2333    2203.0   2449.0   2860.0   3054.0
# TOTAL,THS_PER,T,UK      2459    2559    2534.0   2437.0   1996.0   1746.0
# TOTAL,THS_PER,T,US     14825   13747   12506.0  11459.0   9616.0   8297.0
#
#                          2016
# age,unit,sex,geo\time
# TOTAL,PC_ACT,T,AT          6.0
# TOTAL,PC_ACT,T,BE          7.8
# TOTAL,PC_ACT,T,BG          7.6
# TOTAL,PC_ACT,T,CY         13.0
# TOTAL,PC_ACT,T,CZ          4.0
# TOTAL,PC_ACT,T,DE          4.1
# TOTAL,PC_ACT,T,DK          6.2
# TOTAL,PC_ACT,T,EA18       10.0
# TOTAL,PC_ACT,T,EA19       10.0
# TOTAL,PC_ACT,T,EE          6.8
# TOTAL,PC_ACT,T,EL         23.6
# TOTAL,PC_ACT,T,ES         19.6
# TOTAL,PC_ACT,T,EU27        8.5
# TOTAL,PC_ACT,T,EU28        8.6
# TOTAL,PC_ACT,T,FI          8.8
# TOTAL,PC_ACT,T,FR         10.1
# TOTAL,PC_ACT,T,HR         13.4
# TOTAL,PC_ACT,T,HU          5.1
# TOTAL,PC_ACT,T,IE          7.9
# TOTAL,PC_ACT,T,IS          3.0
# TOTAL,PC_ACT,T,IT         11.7
# TOTAL,PC_ACT,T,JP          3.1
# TOTAL,PC_ACT,T,LT          7.9
# TOTAL,PC_ACT,T,LU          6.3
# TOTAL,PC_ACT,T,LV          9.6
# TOTAL,PC_ACT,T,MT          4.7
# TOTAL,PC_ACT,T,NL          6.0
# TOTAL,PC_ACT,T,NO          4.7
# TOTAL,PC_ACT,T,PL          6.2
# TOTAL,PC_ACT,T,PT         11.2
# ...                        ...
# TOTAL,THS_PER,T,EA18   16116.0
# TOTAL,THS_PER,T,EA19   16233.0
# TOTAL,THS_PER,T,EE        47.0
# TOTAL,THS_PER,T,EL      1131.0
# TOTAL,THS_PER,T,ES      4481.0
# TOTAL,THS_PER,T,EU27   20672.0
# TOTAL,THS_PER,T,EU28   20917.0
# TOTAL,THS_PER,T,FI       237.0
# TOTAL,THS_PER,T,FR      2972.0
# TOTAL,THS_PER,T,HR       245.0
# TOTAL,THS_PER,T,HU       235.0
# TOTAL,THS_PER,T,IE       173.0
# TOTAL,THS_PER,T,IS      5883.0
# TOTAL,THS_PER,T,IT      3012.0
# TOTAL,THS_PER,T,JP      2078.0
# TOTAL,THS_PER,T,LT       116.0
# TOTAL,THS_PER,T,LU        18.0
# TOTAL,THS_PER,T,LV        95.0
# TOTAL,THS_PER,T,MT         9.0
# TOTAL,THS_PER,T,NL       538.0
# TOTAL,THS_PER,T,NO       132.0
# TOTAL,THS_PER,T,PL      1063.0
# TOTAL,THS_PER,T,PT       571.0
# TOTAL,THS_PER,T,RO       530.0
# TOTAL,THS_PER,T,SE       366.0
# TOTAL,THS_PER,T,SI        80.0
# TOTAL,THS_PER,T,SK       267.0
# TOTAL,THS_PER,T,TR      3330.0
# TOTAL,THS_PER,T,UK      1599.0
# TOTAL,THS_PER,T,US      7751.0
#
# [109 rows x 27 columns]

# %%
#Create multi index for easy processing.
df["age"] = np.nan
df["unit"]=np.nan
df["sex"]=np.nan
df["geo/time"]=np.nan
for i,indexStr in enumerate(df.index):
    stringList=indexStr.split(',')
    df.iloc[i, df.columns.get_loc('age')] = stringList[0]
    df.iloc[i,df.columns.get_loc('unit')]=stringList[1]
    df.iloc[i,df.columns.get_loc('sex')]=stringList[2]
    df.iloc[i,df.columns.get_loc('geo/time')]=stringList[3]
                
df=df.set_index(['age', 'unit', 'sex','geo/time'])
#Now select the needed latest data

# %%
#This wont load properly for some reason (Claas)

pycountry.countries.get(alpha_2="")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-5c735218e5fd> in <module>()
# ----> 1 pycountry.countries.get(alpha_2="")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pycountry\db.py in load_if_needed(self, *args, **kw)
#      41         if not self._is_loaded:
#      42             self._load()
# ---> 43         return f(self, *args, **kw)
#      44     return load_if_needed
#      45
#
# C:\ProgramData\Anaconda3\lib\site-packages\pycountry\db.py in get(self, **kw)
#      99             raise TypeError('Only one criteria may be given')
#     100         field, value = kw.popitem()
# --> 101         return self.indices[field][value]
#     102
#     103     @lazy_load
#
# KeyError: ''

# %%
#We want the data of the total age and the percentage of the active population of 2016
countryDf=df.loc[('TOTAL', 'PC_ACT', 'T')]["2016 "].copy()
#Dropping columns that do not correspond to a country
countryDf.drop(['EA18','EA19','EU27','EU28'],inplace=True)
#Greece is abbreviated as EL 
nameIndexes=[]
for countryCode in countryDf.index:
    if countryCode =="EL":
        countryCode="GR"
    if countryCode =="UK":
        countryCode="GB"
    nameIndexes.append(pycountry.countries.get(alpha_2=countryCode).name)
countrySeries=pd.Series(countryDf.values,nameIndexes)
